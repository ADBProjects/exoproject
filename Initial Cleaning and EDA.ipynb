# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
import random as random

# %%
testdf = pd.read_csv('exoTest.csv')
trdf = pd.read_csv('exoTrain.csv')

# %%
trdf.shape
# Out:
# (5087, 3198)

# %%
trdf.head()

# %%
trdf['LABEL'] = trdf['LABEL'].map({2: 1, 1: 0})

# %%
ldf = trdf[['LABEL']]
lista = list(ldf.values)
print(lista.count(1))
print(lista.count(0))
# Out:
# 37
# 5050

# %%
ldf['LABEL'].value_counts().plot.bar()

plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 13, 8
plt.title('Distribution of flux values', fontsize=10)
plt.xlabel('Flux values')
plt.ylabel('Flux intensity')
plt.plot(trdf.iloc[0,])
plt.plot(trdf.iloc[1,])
plt.plot(trdf.iloc[2,])
plt.plot(trdf.iloc[3,])
plt.show()

# %%
print(random.randrange(50,5050,1))
print(random.randrange(50,5050,1))
print(random.randrange(50,5050,1))
print(random.randrange(50,5050,1))
# Out:
# 2575
# 919
# 2625
# 1384

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 13, 8
plt.title('Distribution of flux values', fontsize=10)
plt.xlabel('Flux values')
plt.ylabel('Flux intensity')
plt.plot(trdf.iloc[2575,])
plt.plot(trdf.iloc[919,])
plt.plot(trdf.iloc[2625,])
plt.plot(trdf.iloc[1384,])
plt.show()
